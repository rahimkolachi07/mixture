# %%
a= input("Enter a list of numbers, separated by spaces: ").split()
b = 0
print('the list is given as;',a)
for i in a:
    if int(i) % 2 == 0:
        print(i,'even number')
        b += int(i)

print("Sum of even numbers:", b)
# Out:
# Enter a list of numbers, separated by spaces: 2 3 4
# the list is given as; ['2', '3', '4']
# 2 even number
# 4 even number
# Sum of even numbers: 6
