# %%
! pip install -q langchain transformers sentence_transformers llama-index
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 759.0/759.0 kB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 98.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.2/362.2 kB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 27.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.6 MB/s eta 0:00:00
# ...

# %%
from llama_index import SimpleDirectoryReader, LangchainEmbedding, GPTListIndex, GPTVectorStoreIndex, PromptHelper
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index import LLMPredictor, ServiceContext
import torch
from langchain.llms.base import LLM
from transformers import pipeline

# %%
class customLLM(LLM):
    model_name = "google/flan-t5-large"
    pipeline = pipeline("text2text-generation", model=model_name, device=0, model_kwargs={"torch_dtype":torch.bfloat16})

    def _call(self, prompt, stop=None):
        return self.pipeline(prompt, max_length=9999)[0]["generated_text"]
 
    def _identifying_params(self):
        return {"name_of_model": self.model_name}

    def _llm_type(self):
        return "custom"


llm_predictor = LLMPredictor(llm=customLLM())

# %%
text1 ="The flight chatbot is designed to assist users in finding and booking flights, as well as providing information about flights and airlines. Features: Flight search: Users can search for flights by entering their origin, destination, and travel dates. Flight booking: Users can book flights directly through the chatbot. Flight status: Users can check the status of their flight or any other flight by entering the flight number or route. Airport information: Users can get information about airports such as terminal maps, amenities, and transportation options. Airline information: Users can get information about airlines such as baggage allowance, in-flight amenities, and loyalty programs. Frequently asked questions: The chatbot can answer common questions about flights, such as check-in procedures, baggage policies, and travel requirements. User interface: The chatbot can be accessed through a messaging platform such as Facebook Messenger, WhatsApp, or a dedicated app. Integration: The chatbot can be integrated with a flight booking system or airline API to provide real-time flight information and pricing. Natural language processing: The chatbot uses natural language processing to understand user requests and provide relevant responses. Security: The chatbot uses encryption and other security measures to protect user data and ensure secure transactions. Support: The chatbot provides customer support through a help desk or live chat feature, and can escalate issues to human agents if necessary. Hello and welcome to our flight chatbot. How can I assist you today? Hi there! I am here to help you with any flight-related questions you may have. Good day! How can I assist you with your travel plans?  What is your preferred departure date and destination? Would you like to search for flights, check your itinerary, or make a booking? Do you have any special requirements such as dietary restrictions or wheelchair assistance? Can I help you with any other travel-related questions or concerns? Please let me know if there is anything else I can help you with. Have a great day!  If you are looking to travel from one city to another, we have got a range of flights available for you. Simply tell us the departure city and arrival city, and we will show you all the flights that match your search. You can also check the flight schedule for the day and time that suits you best. If you want to know more details about a specific flight, just give us the flight number and we will provide you with all the relevant information. Once you ve found the flight you want, booking is easy. You can either book online through our website or call our customer service team to book over the phone. The fare for your flight will depend on a number of factors, such as the time of year and how far in advance you book. If you need to change or cancel your flight booking, you can do so easily through our website or by calling our customer service team.  When it comes to check-in and boarding, we ve got you covered. We ll let you know the check-in procedure for your flight and what time your flight is scheduled to board. You can also choose your seat on the flight to make sure you get the best view. As for baggage, we will tell you the baggage allowance for your flight and whether you can bring a carry-on bag on board. If you need to check your baggage, we will guide you through the process. We understand that flight status is important to you, so we ll keep you updated on any changes to your flight schedule. You can check the status of your flight online or by calling our customer service team. If there are any delays or cancellations for your flight, we will notify you as soon as possible. Finally, we know that additional information is important to you. We ll provide you with our airlines policy on pets, so you can make sure your furry friends are taken care of. We ll also let you know if theres in-flight entertainment on your flight, and what the food and drink policy is. At every step of the way, we are here to make sure your flight experience
Check with the airline or contact our customer service representative for specific details.Airlines provide assistance for passengers with autism or sensory processing disorders. While you may not be able to select a specific type during the booking process, many airlines offer resources and support to help passengers with autism or sensory processing disorders have a comfortable travel experience. Contact our customer service representative for assistance and information on available services.Airlines have medical assistance and emergency services available onboard their flights. While you may not be able to select a specific type during the booking process, cabin crew members are trained to handle medical situations and can provide necessary assistance during emergencies. In case of specific medical needs, it is recommended to inform the airline prior to your flight.Some airlines provide inflight sign language interpretation or communication support for passengers with hearing impairments or deafness. While you may not be able to select a specific type during the booking process, many airlines aim to provide inclusive services by offering sign language interpretation or communication aids. Check with the airline or contact our customer service representative for specific details.Airports often offer assistance for passengers with cognitive disabilities or developmental disorders. While you may not be able to select a specific type during the flight booking process, many airports provide support services, including dedicated staff and specialized facilities, to assist passengers with cognitive disabilities or developmental disorders. Contact our customer service representative for assistance and information on available services.Airlines may offer inflight activities or amenities for children with special needs. While you may not be able to select a specific type during the booking process, certain airlines provide resources and amenities to cater to the needs of children with special needs. Check with the airline or contact our customer service representative for specific details.Airlines provide assistance for passengers with anxiety or fear of flying. While you may not be able to select a specific type during the booking process, many airlines offer resources, such as informative materials or dedicated support, to help passengers manage their anxiety or fear. Contact our customer service representative for assistance and information on available services.Inflight language interpretation or translation services may be available on certain airlines or routes. While you may not be able to select a specific type during the booking process, some airlines offer language interpretation services or multilingual cabin crew members to assist passengers who require language support. Contact our customer service representative for specific details.Airlines offer assistance for passengers with mobility impairments or wheelchair users. During the booking process, you can request wheelchair assistance or indicate your specific needs. The airline will make arrangements to ensure a smooth travel experience. Contact our customer service representative for assistance and information on available services.Airlines may provide onboard pet care services or amenities to ensure the comfort and well-being of pets traveling in the cabin. While you may not be able to select a specific type during the booking process, certain airlines offer these services. Check with the airline or contact our customer service representative for specific details.Some airlines offer inflight exercise or stretching programs to promote passenger well-being during the flight. While you may not be able to select a specific type during the booking process, certain airlines provide these programs as part of their inflight entertainment or wellness initiatives. Check with the airline or contact our customer service representative for specific details.Airlines often provide child restraint systems or infant bassinets to ensure the safety and comfort of young passengers. While you may not be able to select a specific type during the booking process, certain airlines offer these amenities for families traveling with infants or young children. Check with the airline or contact our customer service representative for specific details.Airlines may offer pet-friendly seating arrangements, such as designated areas for passengers traveling with pets in the cabin. While you may not be able to select a specific type during the booking process, certain airlines provide these options to accommodate passengers traveling with their pets. Check with the airline or contact our customer service representative for specific details.Some airlines provide onboard socializing or networking opportunities, such as designated communal areas or organized events. While you may not be able to select a specific type during the booking process, certain airlines offer these experiences to enhance the travel experience and facilitate connections among passengers. Check with the airline or contact our customer service representative for specific details.Airlines often provide inflight pet handling assistance or services to ensure the well-being of pets traveling in the cabin. While you may not be able to select a specific type during the booking process, certain airlines offer these services to assist passengers with managing their pets during the flight. Check with the airline or contact our customer service representative for specific details."

# %%
hfemb = HuggingFaceEmbeddings()
embed_model = LangchainEmbedding(hfemb)

# %%
from llama_index import Document

text_list = [text1]

documents = [Document(t) for t in text_list]

# %%
service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor, embed_model=embed_model)
index = GPTVectorStoreIndex.from_documents(documents, service_context=service_context)

# %%
import logging

logging.getLogger().setLevel(logging.CRITICAL)

# %%
query_engine = index.as_query_engine()
response = query_engine.query("How to book a flight")
print(response)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1847 > 512). Running this sequence through the model will result in indexing errors
# You can book a flight online through the airline's website or through a travel booking website

# %%
query_engine = index.as_query_engine()
response = query_engine.query("What best time flight booking")
print(response)
# Out:
# 6-8 weeks before your travel date

# %%
query_engine = index.as_query_engine()
response = query_engine.query("hey")
data=str(response)
print(data)
# Out:
# Hello and welcome to our flight chatbot. How can I assist you today?

# %%
import json
import requests
from prettytable import PrettyTable

response = "Yes"
data = str(response)
print(data)

if 'Yes' in data:
    origin = input("Enter the origin airport code: ")
    destination = input("Enter the destination airport code: ")
    departure_date = input("Enter the departure date (YYYY-MM-DD): ")
    return_date = input("Enter the return date (YYYY-MM-DD): ")
    adults = int(input("Enter the number of adults: "))
    children = int(input("Enter the number of children: "))
    children_age = [int(age) for age in input("Enter the ages of the children separated by commas: ").split(',') if age.strip()]
    cabin_type = input("Enter the cabin type (Y for Economy, W for Premium Economy, C for Business, F for First Class): ")
    limit = int(input("Enter the number of results to display per page: "))
    offset = int(input("Enter the page number: "))

    url = "http://34.200.242.60/api/search-flights"
    headers = {
        "Authorization": "Bearer 25|GmUlr8C9fIP01Fq8mged3Z9JK6HQiioIqBKJ7dRX",
        "Accept": "application/json",
    }

    data = {
        "origin": origin,
        "destination": destination,
        "departure_date": departure_date,
        "return_date": return_date,
        "adults": adults,
        "children": children,
        "children_age": children_age,
        "cabin_type": cabin_type,
        "pagination": {
            "limit": limit,
            "offset": offset
        },
        "max_stops": 0,
        "max_duration": 2000,
        "sort_by": "duration"
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        flight_data = response.json()
        print(flight_data)
        search_results = flight_data['data']['SearchResult']

        for result in search_results:
            print("Flight Details:")
            table = PrettyTable()
            table.field_names = ["Flight Number", "Departure", "Arrival", "Duration (min)", "Origin", "Destination"]

            for itinerary in result['AirItinerary']:
                for segment in itinerary['FlightSegment']:
                    table.add_row([
                        segment['FlightNumber'],
                        segment['DepartureDateTime'],
                        segment['ArrivalDateTime'],
                        segment['ElapsedTime'],
                        segment['DepartureAirportDetails']['LocationCode'],
                        segment['ArrivalAirportDetails']['LocationCode']
                    ])

            print(table)

            print("Charges:")
            charges_table = PrettyTable()
            charges_table.field_names = ["Base Fare", "Taxes", "Total Fare"]

            for pricing_info in result['AirItineraryPricingInfo']:
                itin_total_fare = pricing_info['ItinTotalFare']
                charges_table.add_row([
                    f"${itin_total_fare['BaseFare']['Amount']} ({itin_total_fare['BaseFare']['CurrencyCode']})",
                    f"${itin_total_fare['Taxes']['Tax'][0]['Amount']} ({itin_total_fare['Taxes']['Tax'][0]['CurrencyCode']})",
                    f"${itin_total_fare['TotalFare']['Amount']} ({itin_total_fare['TotalFare']['CurrencyCode']})"
                ])


            print(charges_table)
            print("\n")

    else:
        print(f"Failed to get flight search results. Status code: {response.status_code}")
else:
    print("The response does not contain 'yes'.")
# Out:
# Yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9d540c531d9c> in <cell line: 9>()
#       8
#       9 if 'Yes' in data:
# ---> 10     origin = input("Enter the origin airport code: ")
#      11     destination = input("Enter the destination airport code: ")
#      12     departure_date = input("Enter the departure date (YYYY-MM-DD): ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
#ORD to JFK on May 20.

# %%
import json
import requests
from prettytable import PrettyTable

response = "Yes"
data = str(response)
print(data)

if 'Yes' in data:
    origin = input("Enter the origin airport code: ")
    destination = input("Enter the destination airport code: ")
    departure_date = input("Enter the departure date (YYYY-MM-DD): ")
    return_date = input("Enter the return date (YYYY-MM-DD): ")
    adults = int(1)
    children = int(0)
    children_age = int(0)
    cabin_type = "Y"
    limit = int(1)
    offset = int(1)

    url = "http://34.200.242.60/api/search-flights"
    headers = {
        "Authorization": "Bearer 25|GmUlr8C9fIP01Fq8mged3Z9JK6HQiioIqBKJ7dRX",
        "Accept": "application/json",
    }

    data = {
        "origin": origin,
        "destination": destination,
        "departure_date": departure_date,
        "return_date": return_date,
        "adults": adults,
        "children": children,
        "children_age": children_age,
        "cabin_type": cabin_type,
        "pagination": {
            "limit": limit,
            "offset": offset
        },
        "max_stops": 0,
        "max_duration": 2000,
        "sort_by": "duration"
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        flight_data = response.json()
        print(flight_data)
        search_results = flight_data['data']['SearchResult']

        for result in search_results:
            print("Flight Details:")
            table = PrettyTable()
            table.field_names = ["Flight Number", "Departure", "Arrival", "Duration (min)", "Origin", "Destination"]

            for itinerary in result['AirItinerary']:
                for segment in itinerary['FlightSegment']:
                    table.add_row([
                        segment['FlightNumber'],
                        segment['DepartureDateTime'],
                        segment['ArrivalDateTime'],
                        segment['ElapsedTime'],
                        segment['DepartureAirportDetails']['LocationCode'],
                        segment['ArrivalAirportDetails']['LocationCode']
                    ])

            print(table)

            print("Charges:")
            charges_table = PrettyTable()
            charges_table.field_names = ["Base Fare", "Taxes", "Total Fare"]

            for pricing_info in result['AirItineraryPricingInfo']:
                itin_total_fare = pricing_info['ItinTotalFare']
                charges_table.add_row([
                    f"${itin_total_fare['BaseFare']['Amount']} ({itin_total_fare['BaseFare']['CurrencyCode']})",
                    f"${itin_total_fare['Taxes']['Tax'][0]['Amount']} ({itin_total_fare['Taxes']['Tax'][0]['CurrencyCode']})",
                    f"${itin_total_fare['TotalFare']['Amount']} ({itin_total_fare['TotalFare']['CurrencyCode']})"
                ])


            print(charges_table)
            print("\n")

    else:
        print(f"Failed to get flight search results. Status code: {response.status_code}")
else:
    print("The response does not contain 'yes'.")

# %%
import requests
from prettytable import PrettyTable


def print_line(char, length):
    print(char * length)

def print_header(header, width):
    print_line("=", width)
    print(f"| {header:<{width - 3}}|")
    print_line("=", width)

def print_row(data, col_widths):
    row = "|"
    for i, value in enumerate(data):
        row += f" {value:<{col_widths[i] - 1}}|"
    print(row)
    print_line("-", sum(col_widths))

response = "Yes"
data = str(response)
print(data)

if 'Yes' in data:
    origin = "ORD"#input("Enter the origin airport code: ")
    destination = "JFK"#input("Enter the destination airport code: ")
    departure_date = "2023-05-20"#input("Enter the departure date (YYYY-MM-DD): ")
    return_date = "2023-06-20" #input("Enter the return date (YYYY-MM-DD): ")
    adults = int(1)
    children = int(0)
    children_age = int(0)
    cabin_type = "Y"
    limit = int(1)
    offset = int(1)

    url = "http://34.200.242.60/api/search-flights"
    headers = {
        "Authorization": "Bearer 25|GmUlr8C9fIP01Fq8mged3Z9JK6HQiioIqBKJ7dRX",
        "Accept": "application/json",
    }

    data = {
        "origin": origin,
        "destination": destination,
        "departure_date": departure_date,
        "return_date": return_date,
        "adults": adults,
        "children": children,
        "children_age": children_age,
        "cabin_type": cabin_type,
        "pagination": {
            "limit": limit,
            "offset": offset
        },
        "max_stops": 0,
        "max_duration": 2000,
        "sort_by": "duration"
    }

    response = requests.post(url, headers=headers, json=data)

    if response.status_code == 200:
        flight_data = response.json()
        print(flight_data)
        search_results = flight_data['data']['SearchResult']

        for result in search_results:
            preference_satisfied = False

            while not preference_satisfied:
                print("Flight Details:")
                table = PrettyTable()
                table.field_names = ["Flight Number", "Departure", "Arrival", "Duration (min)", "Origin", "Destination"]

                origin_destination_information = []
                rph_counter = 1

                for itinerary in result['AirItinerary']:
                    od_info = {}
                    od_info["RPH"] = rph_counter

                    for segment in itinerary['FlightSegment']:
                        table.add_row([
                            segment['FlightNumber'],
                            segment['DepartureDateTime'],
                            segment['ArrivalDateTime'],
                            segment['ElapsedTime'],
                            segment['DepartureAirportDetails']['LocationCode'],
                            segment['ArrivalAirportDetails']['LocationCode']
                        ])

                        od_info["DepartureDateTime"] = segment["DepartureDateTime"]
                        od_info["OriginLocation"] = {"LocationCode": segment["DepartureAirportDetails"]["LocationCode"]}
                        od_info["DestinationLocation"] = {"LocationCode": segment["ArrivalAirportDetails"]["LocationCode"]}
                        od_info["TPA_Extensions"] = {
                            "Flight": [
                                {
                                    "Number": segment["FlightNumber"],
                                    "DepartureDateTime": segment["DepartureDateTime"],
                                    "ArrivalDateTime": segment["ArrivalDateTime"],
                                    "ClassOfService": segment["ResBookDesigCode"],
                                    "OriginLocation": {"LocationCode": segment["DepartureAirportDetails"]["LocationCode"]},
                                    "DestinationLocation": {"LocationCode": segment["ArrivalAirportDetails"]["LocationCode"]},
                                    "Airline": {
                                        "Operating": segment["OperatingAirline"]["Code"],
                                        "Marketing": segment["MarketingAirline"]["Code"]
                                  }


                                }
                            ]
                        }

                    origin_destination_information.append(od_info)
                    rph_counter += 1

                print(table)

                print("Charges:")
                charges_table = PrettyTable()
                charges_table.field_names = ["Base Fare", "Taxes", "Total Fare"]

                for pricing_info in result['AirItineraryPricingInfo']:
                    itin_total_fare = pricing_info['ItinTotalFare']
                    charges_table.add_row([
                        f"${itin_total_fare['BaseFare']['Amount']} ({itin_total_fare['BaseFare']['CurrencyCode']})",
                        f"${itin_total_fare['Taxes']['Tax'][0]['Amount']} ({itin_total_fare['Taxes']['Tax'][0]['CurrencyCode']})",
                        f"${itin_total_fare['TotalFare']['Amount']} ({itin_total_fare['TotalFare']['CurrencyCode']})"
                    ])

                print(charges_table)

                preference_check = input("Did I get your preference right? (yes/no): ")

                if preference_check.lower() == "yes":
                    preference_satisfied = True
                else:
                    # Revalidate Flight Price API
                    revalidate_url = "http://34.200.242.60/api/revalidate-flight"  # Replace with the actual URL
                    revalidate_headers = {
                        "Authorization": "Bearer 25|GmUlr8C9fIP01Fq8mged3Z9JK6HQiioIqBKJ7dRX",
                        "Accept": "application/json",
                    }
                    revalidate_data = {
                        "TravelerInfoSummary": {
                            "SeatsRequested": [
                                1
                            ],
                            "AirTravelerAvail": [
                                {
                                    "PassengerTypeQuantity": [
                                        {
                                            "Code": "ADT",
                                            "Quantity": 1
                                        }
                                    ]
                                }
                            ]
                        },
                        "OriginDestinationInformation": origin_destination_information
                    }

                    revalidate_response = requests.post(revalidate_url, headers=revalidate_headers, json=revalidate_data)

                    if revalidate_response.status_code == 200:
                        revalidate_data = revalidate_response.json()
                        # Process the revalidated data as needed
                    else:
                        print(f"Failed to revalidate flight price. Status code: {revalidate_response.status_code}")

    else:
        print(f"Failed to get flight search results. Status code: {response.status_code}")
else:
    print("The response does not contain 'yes'.")


               
# Add this after displaying the flight search results and asking if the preference is right
book_flight = input("Should I book this flight for you? (yes/no): ")

if book_flight.lower() == "yes":
    # Execute the booking code
    import json

    url = "http://34.200.242.60/api/book-flight"

    headers = {
        "Authorization": "Bearer 25|GmUlr8C9fIP01Fq8mged3Z9JK6HQiioIqBKJ7dRX",
        "Accept": "application/json",
        "Content-Type": "application/json"
    }

    data = {
        "booking_id": "HJIHML96",
        "travelers": [
            {
                "givenName": "John",
                "surname": "Doe",
                "birthDate": "1990-01-23",
                "passengerCode": "ADT",
                "gender": "Male",
                "email": "john@yopmail.com",
                "phone_number": "98745213"
            }
        ],
        "flightDetails": {
            "RPH": "1",
            "DepartureDateTime": "2023-04-29T19:50:00",
            "OriginLocation": {
                "LocationCode": origin
            },
            "DestinationLocation": {
                "LocationCode": destination
            },
            "TPA_Extensions": {
                "CabinPref": {
                    "Cabin": "Y",
                    "PreferLevel": "Preferred"
                },
                "Flight": [
                    {
                        "Number": 1211,
                        "DepartureDateTime": "2023-04-29T19:50:00",
                        "ArrivalDateTime": "2023-04-29T22:49:00",
                        "ClassOfService": "L",
                        "OriginLocation": {
                            "LocationCode": "JFK"
                        },
                        "DestinationLocation": {
                            "LocationCode": "LAS"
                        },
                        "Airline": {
                            "Operating": "B6",
                            "Marketing": "B6"
                        },
                        "MarriageGrp": "O"
                    }
                ]
            }
        }
    }

    response = requests.post(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        print("Flight booked successfully!")
                # Travelers table
        traveler_col_widths = [12, 10, 12, 16, 8, 20, 14]
        traveler_headers = ["Given Name", "Surname", "Birth Date", "Passenger Code", "Gender", "Email", "Phone Number"]

        print_header("Travelers", sum(traveler_col_widths))
        print_row(traveler_headers, traveler_col_widths)

        for traveler in data["travelers"]:
            traveler_data = [
                traveler["givenName"],
                traveler["surname"],
                traveler["birthDate"],
                traveler["passengerCode"],
                traveler["gender"],
                traveler["email"],
                traveler["phone_number"]
            ]
            print_row(traveler_data, traveler_col_widths)

        # Flight details table
        flight_col_widths = [14, 18, 18, 18, 8, 14, 18, 18, 16]
        flight_headers = ["Flight Number", "Departure Time", "Arrival Time", "Class of Service", "Origin", "Destination",
                          "Operating Airline", "Marketing Airline", "Marriage Group"]

        print_header("Flight Details", sum(flight_col_widths))
        print_row(flight_headers, flight_col_widths)

        for flight in data["flightDetails"]["TPA_Extensions"]["Flight"]:
            flight_data = [
                flight["Number"],
                flight["DepartureDateTime"],
                flight["ArrivalDateTime"],
                flight["ClassOfService"],
                flight["OriginLocation"]["LocationCode"],
                flight["DestinationLocation"]["LocationCode"],
                flight["Airline"]["Operating"],
                flight["Airline"]["Marketing"],
                flight["MarriageGrp"]
            ]
            print_row(flight_data, flight_col_widths)
        print(response.json())



else:
    print("Flight booking not confirmed.")
# Out:
# Yes
# ...

# %%
print(f"Revalidate response: {revalidate_response.text}")
# Out:
# Revalidate response: {"statusCode":400,"message":"No data available please try again later.","data":{"status":"NotProcessed","reportingSystem":"RAF","timeStamp":"2023-05-06T19:51:21+00:00","type":"Validation","errorCode":"ERR.RAF.VALIDATION","instance":"raf-darhlc005-9080","message":"[{\"level\":\"error\",\"schema\":{\"loadingURI\":\"#\",\"pointer\":\"\/definitions\/org.opentravel.ota._2003._05.OTAAirLowFareSearchRQ.OriginDestinationInformation\/properties\/RPH\"},\"instance\":{\"pointer\":\"\/OTA_AirLowFareSearchRQ\/OriginDestinationInformation\/0\/RPH\"},\"domain\":\"validation\",\"keyword\":\"type\",\"message\":\"instance type (integer) does not match any allowed primitive type (allowed: [\\\"string\\\"])\",\"found\":\"integer\",\"expected\":[\"string\"]}]"}}

# %%
def print_line(char, length):
    print(char * length)

def print_header(header, width):
    print_line("=", width)
    print(f"| {header:<{width - 3}}|")
    print_line("=", width)

def print_row(data, col_widths):
    row = "|"
    for i, value in enumerate(data):
        row += f" {value:<{col_widths[i] - 1}}|"
    print(row)
    print_line("-", sum(col_widths))


# Travelers table
traveler_col_widths = [12, 10, 12, 16, 8, 20, 14]
traveler_headers = ["Given Name", "Surname", "Birth Date", "Passenger Code", "Gender", "Email", "Phone Number"]

print_header("Travelers", sum(traveler_col_widths))
print_row(traveler_headers, traveler_col_widths)

for traveler in data["travelers"]:
    traveler_data = [
        traveler["givenName"],
        traveler["surname"],
        traveler["birthDate"],
        traveler["passengerCode"],
        traveler["gender"],
        traveler["email"],
        traveler["phone_number"]
    ]
    print_row(traveler_data, traveler_col_widths)

# Flight details table
flight_col_widths = [14, 18, 18, 18, 8, 14, 18, 18, 16]
flight_headers = ["Flight Number", "Departure Time", "Arrival Time", "Class of Service", "Origin", "Destination",
                  "Operating Airline", "Marketing Airline", "Marriage Group"]

print_header("Flight Details", sum(flight_col_widths))
print_row(flight_headers, flight_col_widths)

for flight in data["flightDetails"]["TPA_Extensions"]["Flight"]:
    flight_data = [
        flight["Number"],
        flight["DepartureDateTime"],
        flight["ArrivalDateTime"],
        flight["ClassOfService"],
        flight["OriginLocation"]["LocationCode"],
        flight["DestinationLocation"]["LocationCode"],
        flight["Airline"]["Operating"],
        flight["Airline"]["Marketing"],
        flight["MarriageGrp"]
    ]
    print_row(flight_data, flight_col_widths)
# Out:
# ...
# | Travelers                                                                                |
# ...
# | Given Name | Surname  | Birth Date | Passenger Code | Gender | Email              | Phone Number |
# --------------------------------------------------------------------------------------------
# | John       | Doe      | 1990-01-23 | ADT            | Male   | john@yopmail.com   | 98745213     |
# --------------------------------------------------------------------------------------------
# ...
# | Flight Details                                                                                                                             |
# ...
# | Flight Number| Departure Time   | Arrival Time     | Class of Service | Origin | Destination  | Operating Airline| Marketing Airline| Marriage Group |
# ----------------------------------------------------------------------------------------------------------------------------------------------
# ...
